# %%
import os, glob, json, re

def test_step0_acc_per_client(raw_dir="runs/mid_eval", pattern="client_*.raw"):
    paths = sorted(glob.glob(os.path.join(raw_dir, pattern)))
    if not paths:
        raise FileNotFoundError(f"No files matched: {os.path.join(raw_dir, pattern)}")

    result = {}
    for p in paths:
        # 파일명에서 client id 추출 (예: client_001.raw -> 1)
        m = re.search(r"client_(\d+)\.raw$", os.path.basename(p))
        file_client_id = int(m.group(1)) if m else None

        acc_at_step0 = None
        with open(p, "r", encoding="utf-8") as f:
            for line in f:
                line = line.strip()
                if not line:
                    continue
                try:
                    rec = json.loads(line)
                except json.JSONDecodeError:
                    continue
                if rec.get("split") != "test":
                    continue
                if int(rec.get("step", -1)) != 0:
                    continue

                cid = int(rec.get("client", file_client_id))
                acc = rec.get("acc", None)
                if acc is not None:
                    acc_at_step0 = float(acc)
                    # 동일 파일에 여러 개 있을 일은 보통 없으니 첫 매치에서 종료
                    break

        # step 0 레코드가 존재할 때만 기록
        if acc_at_step0 is not None:
            result[cid] = acc_at_step0

    return result

# 사용 예
step0_dict = test_step0_acc_per_client(raw_dir="raw/mid_eval", pattern="client_*.raw")
print(f"step=0 기록이 있는 클라이언트 수: {len(step0_dict)}")
for cid in sorted(step0_dict):
    print(f"client {cid:03d}: acc_at_step0 = {step0_dict[cid]:.6f}")
# Out:
# step=0 기록이 있는 클라이언트 수: 53
# client 001: acc_at_step0 = 0.575000
# client 002: acc_at_step0 = 0.550000
# client 003: acc_at_step0 = 0.450000
# client 004: acc_at_step0 = 0.650000
# client 005: acc_at_step0 = 0.375000
# client 006: acc_at_step0 = 0.425000
# client 007: acc_at_step0 = 0.600000
# client 008: acc_at_step0 = 0.650000
# client 009: acc_at_step0 = 0.625000
# client 010: acc_at_step0 = 0.475000
# client 011: acc_at_step0 = 0.650000
# client 012: acc_at_step0 = 0.675000
# client 013: acc_at_step0 = 0.525000
# client 014: acc_at_step0 = 0.700000
# client 015: acc_at_step0 = 0.475000
# client 016: acc_at_step0 = 0.550000
# client 017: acc_at_step0 = 0.575000
# client 018: acc_at_step0 = 0.675000
# client 019: acc_at_step0 = 0.375000
# client 020: acc_at_step0 = 0.575000
# client 021: acc_at_step0 = 0.425000
# client 022: acc_at_step0 = 0.525000
# client 023: acc_at_step0 = 0.575000
# client 024: acc_at_step0 = 0.550000
# client 025: acc_at_step0 = 0.500000
# client 026: acc_at_step0 = 0.575000
# client 027: acc_at_step0 = 0.625000
# client 028: acc_at_step0 = 0.475000
# client 029: acc_at_step0 = 0.525000
# client 030: acc_at_step0 = 0.575000
# client 031: acc_at_step0 = 0.600000
# client 032: acc_at_step0 = 0.500000
# client 033: acc_at_step0 = 0.500000
# client 034: acc_at_step0 = 0.575000
# client 035: acc_at_step0 = 0.625000
# client 036: acc_at_step0 = 0.575000
# client 037: acc_at_step0 = 0.550000
# client 038: acc_at_step0 = 0.600000
# client 039: acc_at_step0 = 0.500000
# client 040: acc_at_step0 = 0.400000
# client 041: acc_at_step0 = 0.500000
# client 042: acc_at_step0 = 0.625000
# client 043: acc_at_step0 = 0.575000
# client 044: acc_at_step0 = 0.700000
# client 045: acc_at_step0 = 0.450000
# client 046: acc_at_step0 = 0.625000
# client 047: acc_at_step0 = 0.600000
# client 048: acc_at_step0 = 0.375000
# client 049: acc_at_step0 = 0.425000
# client 050: acc_at_step0 = 0.500000
# client 051: acc_at_step0 = 0.450000
# client 052: acc_at_step0 = 0.550000
# client 053: acc_at_step0 = 0.600000
