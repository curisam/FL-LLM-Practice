    "Hard (G4)":  {0: 0.742, 10: 0.7200000000000001, 20: 0.748, 30: 0.768, 40: 0.76, 50: 0.766, 60: 0.754, 70: 0.7539999999999999, 80: 0.76, 90: 0.786, 100: 0.7779999999999999, 110: 0.7979999999999999, 120: 0.7899999999999999, 130: 0.8019999999999999, 140: 0.778, 150: 0.796, 160: 0.796, 170: 0.8119999999999999, 180: 0.796, 190: 0.796, 200: 0.8220000000000001, 210: 0.8119999999999999, 220: 0.792, 230: 0.8140000000000001, 240: 0.8039999999999999, 250: 0.7999999999999999, 260: 0.8019999999999999, 270: 0.8200000000000001, 280: 0.826, 290: 0.804, 300: 0.812},
}

steps_full = list(range(0, 301, 10))
select_steps = [0, 10, 20, 30, 40, 50, 60, 70, 80]

alg_series = {
    "Single (G1)": list(filtered["FedBis (G1)"].values()),
    "Single (G2)": list(filtered["FedBis (G2)"].values()),
    "Single (G3)": list(filtered["FedBis (G3)"].values()),
    "Single (G4)": list(filtered["FedBis (G4)"].values()),
    "Hard (G1)":   list(filtered["Hard (G1)"].values()),
    "Hard (G2)":   list(filtered["Hard (G2)"].values()),
    "Hard (G3)":   list(filtered["Hard (G3)"].values()),
    "Hard (G4)":   list(filtered["Hard (G4)"].values()),
}

idx = {s: i for i, s in enumerate(steps_full)}
ys_selected = {
    name: [ys[idx[s]] for s in select_steps]
    for name, ys in alg_series.items()
}

# ---- 그림: 정사각형, x축만 공유, y축은 각 서브플롯마다 따로 ----
fig, axes = plt.subplots(
    2, 2,
    figsize=(4, 4),      # 전체 그림을 거의 정사각형으로
    sharex=True,
    sharey=False
)
axes = axes.flatten()

for g_idx, ax in zip([1, 2, 3, 4], axes):
    name_single = f"Single (G{g_idx})"
    name_hard   = f"Hard (G{g_idx})"

    ys_single = ys_selected[name_single]
    ys_hard   = ys_selected[name_hard]

    ax.plot(
        select_steps, ys_single,
        color="#1f77b4", linestyle="-", marker="o",
        label="Single", linewidth=1.2, markersize=4,
    )
    ax.plot(
        select_steps, ys_hard,
        color="#d62728", linestyle="-", marker="s",
        label="Hard", linewidth=1.2, markersize=4,
    )

    ax.set_title(f"Group G{g_idx}", fontsize=9)
    ax.grid(True, alpha=0.3)

# 아래 행에만 x라벨
axes[2].set_xlabel("Fine-tuning steps")
axes[3].set_xlabel("Fine-tuning steps")

# ▶ 모든 서브플롯 x축 눈금: 0,20,40,60,80,100
for ax in axes:
    ax.set_xticks(range(0, 81, 20))

# 공통 범례
handles, labels = axes[0].get_legend_handles_labels()
fig.legend(
    handles, labels,
    loc="lower center",
    ncol=2,
    bbox_to_anchor=(0.5, -0.02),
    frameon=True,
)

plt.tight_layout()
plt.subplots_adjust(bottom=0.20)
plt.savefig("final_synthetic_single_vs_hard_G1_G4_2x2_square.pdf",
            dpi=300, bbox_inches="tight")
plt.show()
